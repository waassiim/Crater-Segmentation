# %%
import tensorflow as tf
import os


from patchify import patchify, unpatchify
import  cv2

# %%
def get_image_source_list(source):
   l=os.listdir(source)
   return l
def return_slised_image(large_image):
  patches = patchify(large_image, (512, 512), step=512)  
  return patches

# %%
def get_train_images(patches,patches_target):
  x_train=[]
  y_train=[]
  for i in range(15):
    for j in range(15):
      x_train.append(patches[i][j])
      y_train.append(patches_target[i][j])
  return x_train,y_train

# %%
def get_train_test_data(l_target,l_data,source,target_source):
    x_train=[]
    y_train=[]
    x_test=[]
    y_test=[]
    for x in range(len(l_target)):
        x_image=cv2.imread(os.path.join(source,l_data[x]),0)
        y_image=cv2.imread(os.path.join(target_source,l_target[x]),0)
        x_patches=return_slised_image(x_image)
        y_patches=return_slised_image(y_image)
        l,s=get_train_images(x_patches,y_patches)
        if x<19:
            x_train=x_train+l
            y_train=y_train+s
        else:
            x_test=x_test+l
            y_test=y_test+s
    x_train=np.array(x_train)
    x_train=x_train/255.0
    y_train=np.array(y_train)
    y_train=y_train/255.0
    x_test=np.array(x_test)
    x_test=x_test/255.0
    y_test=np.array(y_test)
    y_test=y_test/255.0
    
    return x_train,x_test,y_train,y_test

# %%
target_source="Mars_Crater_Segmentation_Dataset_02-32_km_radius/solid" #put the path for thr file of your target
l_target=get_image_source_list(target_source)
print(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng.png']

# %%
print(sorted(l_target))
l_target=sorted(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng.png']

# %%
print(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng.png']

# %%
source=r"clean_images"  # put the preprocessing path
l_data=get_image_source_list(source)
print(l_data)
# Out:
# ['thm_dir_N-30_000.png_good_image.png', 'thm_dir_N-30_030.png_good_image.png', 'thm_dir_N-30_060.png_good_image.png', 'thm_dir_N-30_090.png_good_image.png', 'thm_dir_N-30_120.png_good_image.png', 'thm_dir_N-30_150.png_good_image.png', 'thm_dir_N-30_180.png_good_image.png', 'thm_dir_N-30_210.png_good_image.png', 'thm_dir_N-30_240.png_good_image.png', 'thm_dir_N-30_270.png_good_image.png', 'thm_dir_N-30_300.png_good_image.png', 'thm_dir_N-30_330.png_good_image.png', 'thm_dir_N00_000.png_good_image.png', 'thm_dir_N00_030.png_good_image.png', 'thm_dir_N00_060.png_good_image.png', 'thm_dir_N00_090.png_good_image.png', 'thm_dir_N00_120.png_good_image.png', 'thm_dir_N00_150.png_good_image.png', 'thm_dir_N00_180.png_good_image.png', 'thm_dir_N00_210.png_good_image.png', 'thm_dir_N00_240.png_good_image.png', 'thm_dir_N00_270.png_good_image.png', 'thm_dir_N00_300.png_good_image.png', 'thm_dir_N00_330.png_good_image.png']

# %%
import numpy as np

# %%
x_train,x_test,y_train,y_test = get_train_test_data(l_target,l_data,source,target_source)

# %%
l_target=None
l_data=None
source=None
target_source=None
# hadhom just bich irata7 iram imta3kim chwaya

# %%
from keras.models import Model, load_model
from keras.layers import Dense, Input, BatchNormalization, Dropout
from keras.layers import Add
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D, UpSampling2D
from keras import backend as K
from keras import optimizers
from keras import metrics
import datetime
import glob
import random
from pandas import DataFrame

import numpy as np
import matplotlib.pyplot as plt

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# %%
checkpoint = ModelCheckpoint("model1.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose=1)

# EarlyStopping to find best model with a large number of epochs
earlystop = EarlyStopping(monitor='val_loss',
                          restore_best_weights=True,
                          patience=10,  # number of epochs with no improvement after which training will be stopped
                          verbose=1)

callbacks = [earlystop, checkpoint]

# %%
# model = new_unet()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Dropout, UpSampling2D, Add
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

# --- 1. Define Custom Metrics ---

def dice_coef(y_true, y_pred):
    """
    Dice Coefficient (F1 Score)
    2 * (Intersection) / (Total Area)
    """
    smooth = 1e-6
    # Flatten the tensors
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred):
    """
    Intersection over Union (Jaccard Index)
    (Intersection) / (Union)
    """
    smooth = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def precision_m(y_true, y_pred):
    """Precision: True Positives / (True Positives + False Positives)"""
    smooth = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    true_positives = K.sum(y_true_f * K.round(y_pred_f))
    predicted_positives = K.sum(K.round(y_pred_f))
    return (true_positives + smooth) / (predicted_positives + smooth)

def recall_m(y_true, y_pred):
    """Recall: True Positives / (True Positives + False Negatives)"""
    smooth = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    true_positives = K.sum(y_true_f * K.round(y_pred_f))
    possible_positives = K.sum(y_true_f)
    return (true_positives + smooth) / (possible_positives + smooth)

# --- 2. The Model Architecture ---

def default_unet(): 
     z1 = Input(shape=(512,512,1))

     # Encoder path
     z2 = Conv2D(16, 3, padding='same', activation='relu')(z1)
     p2 = AveragePooling2D(pool_size=2)(z2)

     z3 = Conv2D(24, 3, padding='same', activation='relu')(p2)
     p3 = AveragePooling2D(pool_size=2)(z3)

     z4 = Conv2D(32, 3, padding='same', activation='relu')(p3)
     d4 = Dropout(0.2)(z4)
     p4 = AveragePooling2D(pool_size=2)(d4)

     z5 = Conv2D(48, 3, padding='same', activation='relu')(p4)
     d5 = Dropout(0.2)(z5)
     p5 = AveragePooling2D(pool_size=2)(d5)

     z6 = Conv2D(64, 3, padding='same', activation='relu')(p5)
     d6 = Dropout(0.2)(z6)
     p6 = AveragePooling2D(pool_size=2)(d6)

     z7 = Conv2D(96, 3, padding='same', activation='relu')(p6)
     d7 = Dropout(0.2)(z7)
     p7 = AveragePooling2D(pool_size=2)(d7)

     z8 = Conv2D(128, 3, padding='same', activation='relu')(p7)
     d8 = Dropout(0.2)(z8)
     p8 = AveragePooling2D(pool_size=2)(d8)

     z9 = Conv2D(128, 3, padding='same', activation='relu')(p8)
     d9 = Dropout(0.2)(z9)

     # Decoder path
     u9 = UpSampling2D(size=2)(d9)
     q9 = Conv2D(128, 3, padding='same', activation='relu')(u9)
     d9b = Dropout(0.2)(q9)
     a9 = Add()([d9b,z8])

     u8 = UpSampling2D(size=2)(a9)
     q8 = Conv2D(96, 3, padding='same', activation='relu')(u8)
     d8b = Dropout(0.2)(q8)
     a8 = Add()([d8b,z7])

     u7 = UpSampling2D(size=2)(a8)
     q7 = Conv2D(64, 3, padding='same', activation='relu')(u7)
     d7b = Dropout(0.2)(q7)
     a7 = Add()([d7b,z6])

     u6 = UpSampling2D(size=2)(a7)
     q6 = Conv2D(48, 3, padding='same', activation='relu')(u6)
     d6b = Dropout(0.2)(q6)
     a6 = Add()([d6b,z5])

     u5 = UpSampling2D(size=2)(a6)
     q5 = Conv2D(32, 3, padding='same', activation='relu')(u5)
     d5b = Dropout(0.2)(q5)
     a5 = Add()([d5b,z4])

     u4 = UpSampling2D(size=2)(a5)
     q4 = Conv2D(24, 3, padding='same', activation='relu')(u4)
     a4 = Add()([q4,z3])

     u3 = UpSampling2D(size=2)(a4)
     q3 = Conv2D(16, 3, padding='same', activation='relu')(u3)
     a3 = Add()([q3,z2])

     z_final = Conv2D(1, 3, padding='same', activation='sigmoid')(a3)

     model = Model(inputs = z1, outputs = z_final)
     
     # Compile with the new metrics
     model.compile(
         optimizer='adam', 
         loss='binary_crossentropy', 
         metrics=['accuracy', dice_coef, iou_coef, precision_m, recall_m]
     )
     
     return model

# %%
modell=default_unet()

# %%
resultss = modell.fit(x_train, y_train, validation_split=0.2, batch_size=16, epochs=100, callbacks=callbacks)
# Out:
# Epoch 1/100
# 214/214 [==============================] - ETA: 0s - loss: 0.3408 - accuracy: 0.8838 - dice_coef: 0.1465 - iou_coef: 0.0796 - precision_m: 0.8615 - recall_m: 0.0158
# Epoch 1: val_loss improved from inf to 0.15189, saving model to model1.h5
# 214/214 [==============================] - 629s 3s/step - loss: 0.3408 - accuracy: 0.8838 - dice_coef: 0.1465 - iou_coef: 0.0796 - precision_m: 0.8615 - recall_m: 0.0158 - val_loss: 0.1519 - val_accuracy: 0.9594 - val_dice_coef: 0.1145 - val_iou_coef: 0.0611 - val_precision_m: 0.4613 - val_recall_m: 0.0509
# Epoch 2/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8968 - dice_coef: 0.2525 - iou_coef: 0.1453 - precision_m: 0.6178 - recall_m: 0.1844
# Epoch 2: val_loss improved from 0.15189 to 0.13598, saving model to model1.h5
# 214/214 [==============================] - 607s 3s/step - loss: 0.2873 - accuracy: 0.8968 - dice_coef: 0.2525 - iou_coef: 0.1453 - precision_m: 0.6178 - recall_m: 0.1844 - val_loss: 0.1360 - val_accuracy: 0.9617 - val_dice_coef: 0.1460 - val_iou_coef: 0.0795 - val_precision_m: 0.6906 - val_recall_m: 0.1125
# Epoch 3/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9169 - dice_coef: 0.3818 - iou_coef: 0.2382 - precision_m: 0.7419 - recall_m: 0.3865
# Epoch 3: val_loss improved from 0.13598 to 0.12744, saving model to model1.h5
# 214/214 [==============================] - 609s 3s/step - loss: 0.2429 - accuracy: 0.9169 - dice_coef: 0.3818 - iou_coef: 0.2382 - precision_m: 0.7419 - recall_m: 0.3865 - val_loss: 0.1274 - val_accuracy: 0.9660 - val_dice_coef: 0.1919 - val_iou_coef: 0.1078 - val_precision_m: 0.7670 - val_recall_m: 0.2365
# Epoch 4/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9311 - dice_coef: 0.4761 - iou_coef: 0.3153 - precision_m: 0.8124 - recall_m: 0.4882
# Epoch 4: val_loss improved from 0.12744 to 0.12027, saving model to model1.h5
# 214/214 [==============================] - 612s 3s/step - loss: 0.2117 - accuracy: 0.9311 - dice_coef: 0.4761 - iou_coef: 0.3153 - precision_m: 0.8124 - recall_m: 0.4882 - val_loss: 0.1203 - val_accuracy: 0.9709 - val_dice_coef: 0.2647 - val_iou_coef: 0.1564 - val_precision_m: 0.7183 - val_recall_m: 0.4359
# Epoch 5/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9386 - dice_coef: 0.5310 - iou_coef: 0.3642 - precision_m: 0.8365 - recall_m: 0.5455
# Epoch 5: val_loss improved from 0.12027 to 0.11479, saving model to model1.h5
# 214/214 [==============================] - 620s 3s/step - loss: 0.1913 - accuracy: 0.9386 - dice_coef: 0.5310 - iou_coef: 0.3642 - precision_m: 0.8365 - recall_m: 0.5455 - val_loss: 0.1148 - val_accuracy: 0.9680 - val_dice_coef: 0.3254 - val_iou_coef: 0.1997 - val_precision_m: 0.5783 - val_recall_m: 0.5679
# Epoch 6/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9427 - dice_coef: 0.5611 - iou_coef: 0.3928 - precision_m: 0.8496 - recall_m: 0.5793
# Epoch 6: val_loss improved from 0.11479 to 0.09145, saving model to model1.h5
# 214/214 [==============================] - 603s 3s/step - loss: 0.1806 - accuracy: 0.9427 - dice_coef: 0.5611 - iou_coef: 0.3928 - precision_m: 0.8496 - recall_m: 0.5793 - val_loss: 0.0915 - val_accuracy: 0.9751 - val_dice_coef: 0.4363 - val_iou_coef: 0.2858 - val_precision_m: 0.8034 - val_recall_m: 0.5003
# Epoch 7/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9456 - dice_coef: 0.5839 - iou_coef: 0.4150 - precision_m: 0.8591 - recall_m: 0.6013
# Epoch 7: val_loss did not improve from 0.09145
# 214/214 [==============================] - 602s 3s/step - loss: 0.1724 - accuracy: 0.9456 - dice_coef: 0.5839 - iou_coef: 0.4150 - precision_m: 0.8591 - recall_m: 0.6013 - val_loss: 0.0942 - val_accuracy: 0.9737 - val_dice_coef: 0.3942 - val_iou_coef: 0.2514 - val_precision_m: 0.7035 - val_recall_m: 0.5654
# Epoch 8/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9479 - dice_coef: 0.6003 - iou_coef: 0.4318 - precision_m: 0.8639 - recall_m: 0.6179
# Epoch 8: val_loss did not improve from 0.09145
# 214/214 [==============================] - 601s 3s/step - loss: 0.1648 - accuracy: 0.9479 - dice_coef: 0.6003 - iou_coef: 0.4318 - precision_m: 0.8639 - recall_m: 0.6179 - val_loss: 0.0924 - val_accuracy: 0.9759 - val_dice_coef: 0.3924 - val_iou_coef: 0.2502 - val_precision_m: 0.7606 - val_recall_m: 0.5543
# Epoch 9/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9505 - dice_coef: 0.6213 - iou_coef: 0.4527 - precision_m: 0.8708 - recall_m: 0.6421
# Epoch 9: val_loss improved from 0.09145 to 0.09025, saving model to model1.h5
# 214/214 [==============================] - 601s 3s/step - loss: 0.1582 - accuracy: 0.9505 - dice_coef: 0.6213 - iou_coef: 0.4527 - precision_m: 0.8708 - recall_m: 0.6421 - val_loss: 0.0902 - val_accuracy: 0.9757 - val_dice_coef: 0.4090 - val_iou_coef: 0.2635 - val_precision_m: 0.7363 - val_recall_m: 0.5701
# Epoch 10/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9508 - dice_coef: 0.6232 - iou_coef: 0.4553 - precision_m: 0.8728 - recall_m: 0.6420
# Epoch 10: val_loss did not improve from 0.09025
# 214/214 [==============================] - 602s 3s/step - loss: 0.1566 - accuracy: 0.9508 - dice_coef: 0.6232 - iou_coef: 0.4553 - precision_m: 0.8728 - recall_m: 0.6420 - val_loss: 0.0998 - val_accuracy: 0.9744 - val_dice_coef: 0.3605 - val_iou_coef: 0.2259 - val_precision_m: 0.6836 - val_recall_m: 0.5974
# Epoch 11/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9528 - dice_coef: 0.6388 - iou_coef: 0.4714 - precision_m: 0.8734 - recall_m: 0.6624
# Epoch 11: val_loss did not improve from 0.09025
# 214/214 [==============================] - 599s 3s/step - loss: 0.1508 - accuracy: 0.9528 - dice_coef: 0.6388 - iou_coef: 0.4714 - precision_m: 0.8734 - recall_m: 0.6624 - val_loss: 0.0930 - val_accuracy: 0.9752 - val_dice_coef: 0.3904 - val_iou_coef: 0.2490 - val_precision_m: 0.7379 - val_recall_m: 0.5765
# Epoch 12/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9532 - dice_coef: 0.6434 - iou_coef: 0.4766 - precision_m: 0.8777 - recall_m: 0.6630
# Epoch 12: val_loss improved from 0.09025 to 0.08632, saving model to model1.h5
# 214/214 [==============================] - 600s 3s/step - loss: 0.1489 - accuracy: 0.9532 - dice_coef: 0.6434 - iou_coef: 0.4766 - precision_m: 0.8777 - recall_m: 0.6630 - val_loss: 0.0863 - val_accuracy: 0.9758 - val_dice_coef: 0.4463 - val_iou_coef: 0.2938 - val_precision_m: 0.7220 - val_recall_m: 0.6010
# Epoch 13/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9551 - dice_coef: 0.6545 - iou_coef: 0.4895 - precision_m: 0.8824 - recall_m: 0.6777
# Epoch 13: val_loss improved from 0.08632 to 0.08350, saving model to model1.h5
# 214/214 [==============================] - 599s 3s/step - loss: 0.1446 - accuracy: 0.9551 - dice_coef: 0.6545 - iou_coef: 0.4895 - precision_m: 0.8824 - recall_m: 0.6777 - val_loss: 0.0835 - val_accuracy: 0.9766 - val_dice_coef: 0.4579 - val_iou_coef: 0.3037 - val_precision_m: 0.7919 - val_recall_m: 0.5581
# Epoch 14/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9561 - dice_coef: 0.6657 - iou_coef: 0.5011 - precision_m: 0.8851 - recall_m: 0.6864
# Epoch 14: val_loss did not improve from 0.08350
# 214/214 [==============================] - 600s 3s/step - loss: 0.1399 - accuracy: 0.9561 - dice_coef: 0.6657 - iou_coef: 0.5011 - precision_m: 0.8851 - recall_m: 0.6864 - val_loss: 0.0878 - val_accuracy: 0.9771 - val_dice_coef: 0.4713 - val_iou_coef: 0.3160 - val_precision_m: 0.8449 - val_recall_m: 0.5151
# Epoch 15/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9571 - dice_coef: 0.6727 - iou_coef: 0.5094 - precision_m: 0.8908 - recall_m: 0.6899
# Epoch 15: val_loss did not improve from 0.08350
# 214/214 [==============================] - 600s 3s/step - loss: 0.1370 - accuracy: 0.9571 - dice_coef: 0.6727 - iou_coef: 0.5094 - precision_m: 0.8908 - recall_m: 0.6899 - val_loss: 0.0858 - val_accuracy: 0.9773 - val_dice_coef: 0.4874 - val_iou_coef: 0.3294 - val_precision_m: 0.8373 - val_recall_m: 0.5322
# Epoch 16/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9578 - dice_coef: 0.6795 - iou_coef: 0.5167 - precision_m: 0.8902 - recall_m: 0.6999
# Epoch 16: val_loss did not improve from 0.08350
# 214/214 [==============================] - 601s 3s/step - loss: 0.1340 - accuracy: 0.9578 - dice_coef: 0.6795 - iou_coef: 0.5167 - precision_m: 0.8902 - recall_m: 0.6999 - val_loss: 0.0861 - val_accuracy: 0.9774 - val_dice_coef: 0.4908 - val_iou_coef: 0.3332 - val_precision_m: 0.7833 - val_recall_m: 0.5776
# Epoch 17/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9591 - dice_coef: 0.6908 - iou_coef: 0.5297 - precision_m: 0.8913 - recall_m: 0.7106
# Epoch 17: val_loss did not improve from 0.08350
# 214/214 [==============================] - 600s 3s/step - loss: 0.1295 - accuracy: 0.9591 - dice_coef: 0.6908 - iou_coef: 0.5297 - precision_m: 0.8913 - recall_m: 0.7106 - val_loss: 0.0891 - val_accuracy: 0.9754 - val_dice_coef: 0.4854 - val_iou_coef: 0.3275 - val_precision_m: 0.7211 - val_recall_m: 0.6000
# Epoch 18/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9603 - dice_coef: 0.7004 - iou_coef: 0.5411 - precision_m: 0.8934 - recall_m: 0.7203
# Epoch 18: val_loss did not improve from 0.08350
# 214/214 [==============================] - 597s 3s/step - loss: 0.1252 - accuracy: 0.9603 - dice_coef: 0.7004 - iou_coef: 0.5411 - precision_m: 0.8934 - recall_m: 0.7203 - val_loss: 0.0900 - val_accuracy: 0.9761 - val_dice_coef: 0.4442 - val_iou_coef: 0.2920 - val_precision_m: 0.7461 - val_recall_m: 0.5980
# Epoch 19/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9607 - dice_coef: 0.7019 - iou_coef: 0.5430 - precision_m: 0.8961 - recall_m: 0.7220
# Epoch 19: val_loss did not improve from 0.08350
# 214/214 [==============================] - 599s 3s/step - loss: 0.1248 - accuracy: 0.9607 - dice_coef: 0.7019 - iou_coef: 0.5430 - precision_m: 0.8961 - recall_m: 0.7220 - val_loss: 0.0885 - val_accuracy: 0.9768 - val_dice_coef: 0.4934 - val_iou_coef: 0.3346 - val_precision_m: 0.8075 - val_recall_m: 0.5412
# Epoch 20/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9623 - dice_coef: 0.7142 - iou_coef: 0.5574 - precision_m: 0.8971 - recall_m: 0.7359
# Epoch 20: val_loss did not improve from 0.08350
# 214/214 [==============================] - 601s 3s/step - loss: 0.1190 - accuracy: 0.9623 - dice_coef: 0.7142 - iou_coef: 0.5574 - precision_m: 0.8971 - recall_m: 0.7359 - val_loss: 0.0890 - val_accuracy: 0.9762 - val_dice_coef: 0.4425 - val_iou_coef: 0.2909 - val_precision_m: 0.7525 - val_recall_m: 0.5869
# Epoch 21/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9625 - dice_coef: 0.7196 - iou_coef: 0.5635 - precision_m: 0.8961 - recall_m: 0.7413
# Epoch 21: val_loss did not improve from 0.08350
# 214/214 [==============================] - 598s 3s/step - loss: 0.1172 - accuracy: 0.9625 - dice_coef: 0.7196 - iou_coef: 0.5635 - precision_m: 0.8961 - recall_m: 0.7413 - val_loss: 0.0938 - val_accuracy: 0.9765 - val_dice_coef: 0.4057 - val_iou_coef: 0.2611 - val_precision_m: 0.7473 - val_recall_m: 0.5973
# Epoch 22/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9633 - dice_coef: 0.7225 - iou_coef: 0.5678 - precision_m: 0.8967 - recall_m: 0.7453
# Epoch 22: val_loss improved from 0.08350 to 0.08332, saving model to model1.h5
# 214/214 [==============================] - 598s 3s/step - loss: 0.1152 - accuracy: 0.9633 - dice_coef: 0.7225 - iou_coef: 0.5678 - precision_m: 0.8967 - recall_m: 0.7453 - val_loss: 0.0833 - val_accuracy: 0.9780 - val_dice_coef: 0.5057 - val_iou_coef: 0.3456 - val_precision_m: 0.8156 - val_recall_m: 0.5726
# Epoch 23/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9646 - dice_coef: 0.7334 - iou_coef: 0.5809 - precision_m: 0.9014 - recall_m: 0.7549
# Epoch 23: val_loss did not improve from 0.08332
# 214/214 [==============================] - 598s 3s/step - loss: 0.1103 - accuracy: 0.9646 - dice_coef: 0.7334 - iou_coef: 0.5809 - precision_m: 0.9014 - recall_m: 0.7549 - val_loss: 0.0867 - val_accuracy: 0.9771 - val_dice_coef: 0.5170 - val_iou_coef: 0.3565 - val_precision_m: 0.7848 - val_recall_m: 0.5871
# Epoch 24/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9647 - dice_coef: 0.7351 - iou_coef: 0.5831 - precision_m: 0.8991 - recall_m: 0.7589
# Epoch 24: val_loss did not improve from 0.08332
# 214/214 [==============================] - 601s 3s/step - loss: 0.1101 - accuracy: 0.9647 - dice_coef: 0.7351 - iou_coef: 0.5831 - precision_m: 0.8991 - recall_m: 0.7589 - val_loss: 0.0854 - val_accuracy: 0.9777 - val_dice_coef: 0.4880 - val_iou_coef: 0.3296 - val_precision_m: 0.8821 - val_recall_m: 0.5129
# Epoch 25/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9652 - dice_coef: 0.7379 - iou_coef: 0.5870 - precision_m: 0.9021 - recall_m: 0.7587
# Epoch 25: val_loss did not improve from 0.08332
# 214/214 [==============================] - 601s 3s/step - loss: 0.1085 - accuracy: 0.9652 - dice_coef: 0.7379 - iou_coef: 0.5870 - precision_m: 0.9021 - recall_m: 0.7587 - val_loss: 0.0881 - val_accuracy: 0.9758 - val_dice_coef: 0.5188 - val_iou_coef: 0.3580 - val_precision_m: 0.7231 - val_recall_m: 0.6175
# Epoch 26/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9664 - dice_coef: 0.7472 - iou_coef: 0.5979 - precision_m: 0.9037 - recall_m: 0.7719
# Epoch 26: val_loss did not improve from 0.08332
# 214/214 [==============================] - 600s 3s/step - loss: 0.1045 - accuracy: 0.9664 - dice_coef: 0.7472 - iou_coef: 0.5979 - precision_m: 0.9037 - recall_m: 0.7719 - val_loss: 0.0859 - val_accuracy: 0.9784 - val_dice_coef: 0.5350 - val_iou_coef: 0.3728 - val_precision_m: 0.8488 - val_recall_m: 0.5560
# Epoch 27/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9671 - dice_coef: 0.7552 - iou_coef: 0.6082 - precision_m: 0.9048 - recall_m: 0.7768
# Epoch 27: val_loss did not improve from 0.08332
# 214/214 [==============================] - 600s 3s/step - loss: 0.1013 - accuracy: 0.9671 - dice_coef: 0.7552 - iou_coef: 0.6082 - precision_m: 0.9048 - recall_m: 0.7768 - val_loss: 0.0933 - val_accuracy: 0.9780 - val_dice_coef: 0.5589 - val_iou_coef: 0.3967 - val_precision_m: 0.8339 - val_recall_m: 0.5627
# Epoch 28/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9667 - dice_coef: 0.7512 - iou_coef: 0.6032 - precision_m: 0.9013 - recall_m: 0.7767
# Epoch 28: val_loss did not improve from 0.08332
# 214/214 [==============================] - 601s 3s/step - loss: 0.1025 - accuracy: 0.9667 - dice_coef: 0.7512 - iou_coef: 0.6032 - precision_m: 0.9013 - recall_m: 0.7767 - val_loss: 0.0916 - val_accuracy: 0.9779 - val_dice_coef: 0.5520 - val_iou_coef: 0.3891 - val_precision_m: 0.8166 - val_recall_m: 0.5772
# Epoch 29/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9680 - dice_coef: 0.7627 - iou_coef: 0.6177 - precision_m: 0.9061 - recall_m: 0.7861
# Epoch 29: val_loss did not improve from 0.08332
# 214/214 [==============================] - 598s 3s/step - loss: 0.0985 - accuracy: 0.9680 - dice_coef: 0.7627 - iou_coef: 0.6177 - precision_m: 0.9061 - recall_m: 0.7861 - val_loss: 0.0925 - val_accuracy: 0.9764 - val_dice_coef: 0.5199 - val_iou_coef: 0.3588 - val_precision_m: 0.7547 - val_recall_m: 0.5969
# Epoch 30/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9679 - dice_coef: 0.7621 - iou_coef: 0.6172 - precision_m: 0.9051 - recall_m: 0.7859
# Epoch 30: val_loss did not improve from 0.08332
# 214/214 [==============================] - 600s 3s/step - loss: 0.0983 - accuracy: 0.9679 - dice_coef: 0.7621 - iou_coef: 0.6172 - precision_m: 0.9051 - recall_m: 0.7859 - val_loss: 0.0896 - val_accuracy: 0.9766 - val_dice_coef: 0.5191 - val_iou_coef: 0.3581 - val_precision_m: 0.7452 - val_recall_m: 0.6082
# Epoch 31/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9686 - dice_coef: 0.7664 - iou_coef: 0.6230 - precision_m: 0.9056 - recall_m: 0.7914
# Epoch 31: val_loss did not improve from 0.08332
# 214/214 [==============================] - 598s 3s/step - loss: 0.0961 - accuracy: 0.9686 - dice_coef: 0.7664 - iou_coef: 0.6230 - precision_m: 0.9056 - recall_m: 0.7914 - val_loss: 0.0872 - val_accuracy: 0.9778 - val_dice_coef: 0.5241 - val_iou_coef: 0.3629 - val_precision_m: 0.7854 - val_recall_m: 0.6016
# Epoch 32/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9687 - dice_coef: 0.7670 - iou_coef: 0.6240 - precision_m: 0.9058 - recall_m: 0.7911Restoring model weights from the end of the best epoch: 22.
#
# Epoch 32: val_loss did not improve from 0.08332
# 214/214 [==============================] - 597s 3s/step - loss: 0.0955 - accuracy: 0.9687 - dice_coef: 0.7670 - iou_coef: 0.6240 - precision_m: 0.9058 - recall_m: 0.7911 - val_loss: 0.0888 - val_accuracy: 0.9780 - val_dice_coef: 0.5290 - val_iou_coef: 0.3678 - val_precision_m: 0.8019 - val_recall_m: 0.5810
# Epoch 32: early stopping

# %%
import matplotlib.pyplot as plt

def plot_all_metrics(history):
    # 1. Define the metrics we want to plot
    # These names must match the function names used in model.compile
    metrics = [
        'loss', 
        'accuracy', 
        'dice_coef', 
        'iou_coef', 
        'precision_m', 
        'recall_m'
    ]
    
    # 2. Setup the plot grid (2 rows, 3 columns)
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    axes = axes.flatten() # Flatten 2D array to 1D for easy iteration

    # 3. Loop through metrics and plot
    for i, metric in enumerate(metrics):
        ax = axes[i]
        
        # Check if the metric actually exists in the history object
        if metric in history.history:
            # Get training and validation values
            train_values = history.history[metric]
            val_values = history.history.get(f'val_{metric}') # Use .get() to be safe
            
            # Plotting
            epochs = range(1, len(train_values) + 1)
            ax.plot(epochs, train_values, 'b', label=f'Training {metric}')
            if val_values:
                ax.plot(epochs, val_values, 'r', label=f'Validation {metric}')
            
            # Styling
            ax.set_title(f'Training and Validation {metric.capitalize()}')
            ax.set_xlabel('Epochs')
            ax.set_ylabel(metric)
            ax.legend()
            ax.grid(True)
        else:
            # Hide empty subplots if a metric wasn't calculated
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# --- HOW TO RUN IT ---
# Assuming your training history variable is named 'resultss'
plot_all_metrics(resultss)

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and results 
plot_graphs(resultss, "accuracy")
plot_graphs(resultss, "loss")

# %%
from tensorflow import keras

# %%
custom_objects_dict = {
    'dice_coef': dice_coef,
    'iou_coef': iou_coef,
    'precision_m': precision_m,
    'recall_m': recall_m
}

# --- 3. Load the Model with custom_objects ---
try:
    model = load_model('./model1.h5', custom_objects=custom_objects_dict)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Model loaded successfully!

# %%
testing_pred = model.predict(x_test)
# Out:
# 36/36 [==============================] - 109s 3s/step

# %%
testing = (testing_pred > 0.6).astype(np.uint8)

# %%
ix = random.randint(0, len(x_test))
# ix =936
plt.imshow(x_test[ix])
plt.show()
plt.imshow(np.squeeze(y_test[ix]))
plt.show()
plt.imshow(np.squeeze(testing[ix]))
plt.show()

# %%
print(ix)
